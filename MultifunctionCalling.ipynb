# %%
from Multifunction import Multifunctioncall

# %%
Multifunctioncall.Subfields()
# Out:
# Sub-fields in AI are
# ['Machine Learning',
#  'Neural Networks',
#  'Vision',
#  'Robotics',
#  'Speech Processing',
#  'Natural Language Processing']

# %%
Multifunctioncall.OddREven()
# Out:
# Enter a number:  52452
# 52452 is Even number

# %%
Multifunctioncall.MarriageEligibility()
# Out:
# Your Gender:  Male
# Your Age:  20
# Not Eligible for Marriage

# %%
Multifunctioncall.MarkPercentage()
# Out:
# Subject_1 =  98
# Subject_2 =  87
# Subject_3 =  95
# Subject_4 =  95
# Subject_5 =  93
# Total = 468
# Percentage = 93.60000000000001

# %%
Multifunctioncall.AreaANDPerimeter()
# Out:
# Height:  32
# Breadth:  34
# Area of Triange:  544.0
# Height_1:  2
# Height_2:  4
# Breadth_1:  4
# Perimeter of Triangle:  10
